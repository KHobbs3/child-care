# %% [markdown]
# ## Manitoba - Childcare Scrape
# Retrieved from: https://direct3.gov.mb.ca/86256AF2006B7D4F/Map?OpenForm&AGE=Infant,PreSchool,Nursery,SchoolAge&FAC=Group,Center,Nursery&OPN=Weekdays,Weekends,Evenings,Overnight&VAC=No&MAP=Manitoba&LANG=1

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
import random

# %%
headers = {
    'User-Agent': 'kt 1.0',
    'From': 'khobbs3@uwo.ca'
}

# %%
ages = ['Infant', 'Preschool', 'Nursery', 'School Age']
opn = ['Weekdays', 'Weekends', 'Evenings', 'Overnight']

# %%
domain = 'https://direct3.gov.mb.ca/daycare/fs/fs.nsf/'

# %% [markdown]
# <mark> slow script ahead!!! </mark>

# %%
# initialize variables
url = 'https://direct3.gov.mb.ca/86256AF2006B7D4F/FacilityList?OpenForm&START=1&COUNT=1000&AGE={}&FAC=Group,%20Center,%20Nursery&OPN={}&VAC=No&MAP=Manitoba&AREA=CENTRAL,EASTMAN,INTERLAKE,NORMAN,PARKLAND,THOMPSON,WESTMAN,Brandon,R2_WPG&VIEW=P&LANG=1&ADV=No'
names = list()
links = list()


for a in ages:
    for o in opn:
        print(a, o)
        # change the url to iter through all age and opn options
        req = requests.get(url.format(a, o), headers=headers)
        soup = BeautifulSoup(req.text)
        
        tables = soup.find_all('table')
        
        # get names and request.get links to description pages. Scrape each facility
        for l in tables[3].find_all('a'):
            names.append(l.text)
            links.append(domain+l['href'])
        
            # wait
            time.sleep(random.uniform(1,4))
# Out:
# Infant Weekdays
# Infant Weekends
# Infant Evenings
# Infant Overnight
# Preschool Weekdays
# Preschool Weekends
# Preschool Evenings
# Preschool Overnight
# Nursery Weekdays
# Nursery Weekends
# Nursery Evenings
# Nursery Overnight
# School Age Weekdays
# School Age Weekends
# School Age Evenings
# School Age Overnight

# %%
output = []
out_links = []

# remove duplicates except for those that are Family or Group Child  Care Home *
# duplicates identified on account of duplicate page links

for x,l in zip(names, links):
    if l not in out_links:
        output.append(x)
        out_links.append(l)
    if x == 'Family or Group Child  Care Home *':
        output.append(x)
        out_links.append(l)

# %%
# output = []
# out_links = []

# # remove duplicates except for those that are Family or Group Child  Care Home *

# for x,l in zip(names, links):
#     if x not in output:
#         output.append(x)
#         out_links.append(l)
#     if x == 'Family or Group Child  Care Home *':
#         output.append(x)
#         out_links.append(l)

# %%
print(len(names), len(links))
# Out:
# 1412 1412

# %%
print(len(output), len(out_links))
# Out:
# 859 859

# %%
domain = 'https://direct3.gov.mb.ca'
mb = {}

for l,i in zip(out_links,range(1,len(out_links)+1)):
    print('{} of {}'.format(i, len(out_links)))
    
    r = requests.get(l, headers = headers)
    s = BeautifulSoup(r.text)

    # scrape info
    table = s.find_all('table')[1]
    vals = table.select('td:nth-of-type(2)')
    kys = table.select('td:nth-of-type(1)')

    # make dict
    for k,v in zip(kys, vals):
        if k.text in mb.keys():
            mb[k.text].append(v.text)
        else:
            mb[k.text] = [v.text]

    # fill missing info
    if not any("Address" in k.text for k in kys):
        if "Address:" in mb.keys():
            mb["Address:"].append("None")
        else:
            mb["Address:"] = ["None"]
    else:
        pass

    if not any("Legal Name" in k.text for k in kys):
        if "Legal Name: " in mb.keys():
            mb["Legal Name: "].append("Family or Group Child  Care Home *")
        else:
            mb["Legal Name: "] = ["None"]
    else:
        pass

   

    # wait
    time.sleep(random.uniform(1,4))
# Out:
# 1 of 859
# 2 of 859
# 3 of 859
# 4 of 859
# 5 of 859
# 6 of 859
# 7 of 859
# 8 of 859
# 9 of 859
# 10 of 859
# 11 of 859
# 12 of 859
# 13 of 859
# 14 of 859
# 15 of 859
# 16 of 859
# 17 of 859
# 18 of 859
# 19 of 859
# 20 of 859
# 21 of 859
# 22 of 859
# 23 of 859
# 24 of 859
# 25 of 859
# 26 of 859
# 27 of 859
# 28 of 859
# 29 of 859
# 30 of 859
# 31 of 859
# 32 of 859
# 33 of 859
# 34 of 859
# 35 of 859
# 36 of 859
# 37 of 859
# 38 of 859
# 39 of 859
# 40 of 859
# 41 of 859
# 42 of 859
# 43 of 859
# 44 of 859
# 45 of 859
# 46 of 859
# 47 of 859
# 48 of 859
# 49 of 859
# 50 of 859
# 51 of 859
# 52 of 859
# 53 of 859
# 54 of 859
# 55 of 859
# 56 of 859
# 57 of 859
# 58 of 859
# 59 of 859
# 60 of 859
# 61 of 859
# 62 of 859
# 63 of 859
# 64 of 859
# 65 of 859
# 66 of 859
# 67 of 859
# 68 of 859
# 69 of 859
# 70 of 859
# 71 of 859
# 72 of 859
# 73 of 859
# 74 of 859
# 75 of 859
# 76 of 859
# 77 of 859
# 78 of 859
# 79 of 859
# 80 of 859
# 81 of 859
# 82 of 859
# 83 of 859
# 84 of 859
# 85 of 859
# 86 of 859
# 87 of 859
# 88 of 859
# 89 of 859
# 90 of 859
# 91 of 859
# 92 of 859
# 93 of 859
# 94 of 859
# 95 of 859
# 96 of 859
# 97 of 859
# 98 of 859
# 99 of 859
# 100 of 859
# 101 of 859
# 102 of 859
# 103 of 859
# 104 of 859
# 105 of 859
# 106 of 859
# 107 of 859
# 108 of 859
# 109 of 859
# 110 of 859
# 111 of 859
# 112 of 859
# 113 of 859
# 114 of 859
# 115 of 859
# 116 of 859
# 117 of 859
# 118 of 859
# 119 of 859
# 120 of 859
# 121 of 859
# 122 of 859
# 123 of 859
# 124 of 859
# 125 of 859
# 126 of 859
# 127 of 859
# 128 of 859
# 129 of 859
# 130 of 859
# 131 of 859
# 132 of 859
# 133 of 859
# 134 of 859
# 135 of 859
# 136 of 859
# 137 of 859
# 138 of 859
# 139 of 859
# 140 of 859
# 141 of 859
# 142 of 859
# 143 of 859
# 144 of 859
# 145 of 859
# 146 of 859
# 147 of 859
# 148 of 859
# 149 of 859
# 150 of 859
# 151 of 859
# 152 of 859
# 153 of 859
# 154 of 859
# 155 of 859
# 156 of 859
# 157 of 859
# 158 of 859
# 159 of 859
# 160 of 859
# 161 of 859
# 162 of 859
# 163 of 859
# 164 of 859
# 165 of 859
# 166 of 859
# 167 of 859
# 168 of 859
# 169 of 859
# 170 of 859
# 171 of 859
# 172 of 859
# 173 of 859
# 174 of 859
# 175 of 859
# 176 of 859
# 177 of 859
# 178 of 859
# 179 of 859
# 180 of 859
# 181 of 859
# 182 of 859
# 183 of 859
# 184 of 859
# 185 of 859
# 186 of 859
# 187 of 859
# 188 of 859
# 189 of 859
# 190 of 859
# 191 of 859
# 192 of 859
# 193 of 859
# 194 of 859
# 195 of 859
# 196 of 859
# 197 of 859
# 198 of 859
# 199 of 859
# 200 of 859
# 201 of 859
# 202 of 859
# 203 of 859
# 204 of 859
# 205 of 859
# 206 of 859
# 207 of 859
# 208 of 859
# 209 of 859
# 210 of 859
# 211 of 859
# 212 of 859
# 213 of 859
# 214 of 859
# 215 of 859
# 216 of 859
# 217 of 859
# 218 of 859
# 219 of 859
# 220 of 859
# 221 of 859
# 222 of 859
# 223 of 859
# 224 of 859
# 225 of 859
# 226 of 859
# 227 of 859
# 228 of 859
# 229 of 859
# 230 of 859
# 231 of 859
# 232 of 859
# 233 of 859
# 234 of 859
# 235 of 859
# 236 of 859
# 237 of 859
# 238 of 859
# 239 of 859
# 240 of 859
# 241 of 859
# 242 of 859
# 243 of 859
# 244 of 859
# 245 of 859
# 246 of 859
# 247 of 859
# 248 of 859
# 249 of 859
# 250 of 859
# 251 of 859
# 252 of 859
# 253 of 859
# 254 of 859
# 255 of 859
# 256 of 859
# 257 of 859
# 258 of 859
# 259 of 859
# 260 of 859
# 261 of 859
# 262 of 859
# 263 of 859
# 264 of 859
# 265 of 859
# 266 of 859
# 267 of 859
# 268 of 859
# 269 of 859
# 270 of 859
# 271 of 859
# 272 of 859
# 273 of 859
# 274 of 859
# 275 of 859
# 276 of 859
# 277 of 859
# 278 of 859
# 279 of 859
# 280 of 859
# 281 of 859
# 282 of 859
# 283 of 859
# 284 of 859
# 285 of 859
# 286 of 859
# 287 of 859
# 288 of 859
# 289 of 859
# 290 of 859
# 291 of 859
# 292 of 859
# 293 of 859
# 294 of 859
# 295 of 859
# 296 of 859
# 297 of 859
# 298 of 859
# 299 of 859
# 300 of 859
# 301 of 859
# 302 of 859
# 303 of 859
# 304 of 859
# 305 of 859
# 306 of 859
# 307 of 859
# 308 of 859
# 309 of 859
# 310 of 859
# 311 of 859
# 312 of 859
# 313 of 859
# 314 of 859
# 315 of 859
# 316 of 859
# 317 of 859
# 318 of 859
# 319 of 859
# 320 of 859
# 321 of 859
# 322 of 859
# 323 of 859
# 324 of 859
# 325 of 859
# 326 of 859
# 327 of 859
# 328 of 859
# 329 of 859
# 330 of 859
# 331 of 859
# 332 of 859
# 333 of 859
# 334 of 859
# 335 of 859
# 336 of 859
# 337 of 859
# 338 of 859
# 339 of 859
# 340 of 859
# 341 of 859
# 342 of 859
# 343 of 859
# 344 of 859
# 345 of 859
# 346 of 859
# 347 of 859
# 348 of 859
# 349 of 859
# 350 of 859
# 351 of 859
# 352 of 859
# 353 of 859
# 354 of 859
# 355 of 859
# 356 of 859
# 357 of 859
# 358 of 859
# 359 of 859
# 360 of 859
# 361 of 859
# 362 of 859
# 363 of 859
# 364 of 859
# 365 of 859
# 366 of 859
# 367 of 859
# 368 of 859
# 369 of 859
# 370 of 859
# 371 of 859
# 372 of 859
# 373 of 859
# 374 of 859
# 375 of 859
# 376 of 859
# 377 of 859
# 378 of 859
# 379 of 859
# 380 of 859
# 381 of 859
# 382 of 859
# 383 of 859
# 384 of 859
# 385 of 859
# 386 of 859
# 387 of 859
# 388 of 859
# 389 of 859
# 390 of 859
# 391 of 859
# 392 of 859
# 393 of 859
# 394 of 859
# 395 of 859
# 396 of 859
# 397 of 859
# 398 of 859
# 399 of 859
# 400 of 859
# 401 of 859
# 402 of 859
# 403 of 859
# 404 of 859
# 405 of 859
# 406 of 859
# 407 of 859
# 408 of 859
# 409 of 859
# 410 of 859
# 411 of 859
# 412 of 859
# 413 of 859
# 414 of 859
# 415 of 859
# 416 of 859
# 417 of 859
# 418 of 859
# 419 of 859
# 420 of 859
# 421 of 859
# 422 of 859
# 423 of 859
# 424 of 859
# 425 of 859
# 426 of 859
# 427 of 859
# 428 of 859
# 429 of 859
# 430 of 859
# 431 of 859
# 432 of 859
# 433 of 859
# 434 of 859
# 435 of 859
# 436 of 859
# 437 of 859
# 438 of 859
# 439 of 859
# 440 of 859
# 441 of 859
# 442 of 859
# 443 of 859
# 444 of 859
# 445 of 859
# 446 of 859
# 447 of 859
# 448 of 859
# 449 of 859
# 450 of 859
# 451 of 859
# 452 of 859
# 453 of 859
# 454 of 859
# 455 of 859
# 456 of 859
# 457 of 859
# 458 of 859
# 459 of 859
# 460 of 859
# 461 of 859
# 462 of 859
# 463 of 859
# 464 of 859
# 465 of 859
# 466 of 859
# 467 of 859
# 468 of 859
# 469 of 859
# 470 of 859
# 471 of 859
# 472 of 859
# 473 of 859
# 474 of 859
# 475 of 859
# 476 of 859
# 477 of 859
# 478 of 859
# 479 of 859
# 480 of 859
# 481 of 859
# 482 of 859
# 483 of 859
# 484 of 859
# 485 of 859
# 486 of 859
# 487 of 859
# 488 of 859
# 489 of 859
# 490 of 859
# 491 of 859
# 492 of 859
# 493 of 859
# 494 of 859
# 495 of 859
# 496 of 859
# 497 of 859
# 498 of 859
# 499 of 859
# 500 of 859
# 501 of 859
# 502 of 859
# 503 of 859
# 504 of 859
# 505 of 859
# 506 of 859
# 507 of 859
# 508 of 859
# 509 of 859
# 510 of 859
# 511 of 859
# 512 of 859
# 513 of 859
# 514 of 859
# 515 of 859
# 516 of 859
# 517 of 859
# 518 of 859
# 519 of 859
# 520 of 859
# 521 of 859
# 522 of 859
# 523 of 859
# 524 of 859
# 525 of 859
# 526 of 859
# 527 of 859
# 528 of 859
# 529 of 859
# 530 of 859
# 531 of 859
# 532 of 859
# 533 of 859
# 534 of 859
# 535 of 859
# 536 of 859
# 537 of 859
# 538 of 859
# 539 of 859
# 540 of 859
# 541 of 859
# 542 of 859
# 543 of 859
# 544 of 859
# 545 of 859
# 546 of 859
# 547 of 859
# 548 of 859
# 549 of 859
# 550 of 859
# 551 of 859
# 552 of 859
# 553 of 859
# 554 of 859
# 555 of 859
# 556 of 859
# 557 of 859
# 558 of 859
# 559 of 859
# 560 of 859
# 561 of 859
# 562 of 859
# 563 of 859
# 564 of 859
# 565 of 859
# 566 of 859
# 567 of 859
# 568 of 859
# 569 of 859
# 570 of 859
# 571 of 859
# 572 of 859
# 573 of 859
# 574 of 859
# 575 of 859
# 576 of 859
# 577 of 859
# 578 of 859
# 579 of 859
# 580 of 859
# 581 of 859
# 582 of 859
# 583 of 859
# 584 of 859
# 585 of 859
# 586 of 859
# 587 of 859
# 588 of 859
# 589 of 859
# 590 of 859
# 591 of 859
# 592 of 859
# 593 of 859
# 594 of 859
# 595 of 859
# 596 of 859
# 597 of 859
# 598 of 859
# 599 of 859
# 600 of 859
# 601 of 859
# 602 of 859
# 603 of 859
# 604 of 859
# 605 of 859
# 606 of 859
# 607 of 859
# 608 of 859
# 609 of 859
# 610 of 859
# 611 of 859
# 612 of 859
# 613 of 859
# 614 of 859
# 615 of 859
# 616 of 859
# 617 of 859
# 618 of 859
# 619 of 859
# 620 of 859
# 621 of 859
# 622 of 859
# 623 of 859
# 624 of 859
# 625 of 859
# 626 of 859
# 627 of 859
# 628 of 859
# 629 of 859
# 630 of 859
# 631 of 859
# 632 of 859
# 633 of 859
# 634 of 859
# 635 of 859
# 636 of 859
# 637 of 859
# 638 of 859
# 639 of 859
# 640 of 859
# 641 of 859
# 642 of 859
# 643 of 859
# 644 of 859
# 645 of 859
# 646 of 859
# 647 of 859
# 648 of 859
# 649 of 859
# 650 of 859
# 651 of 859
# 652 of 859
# 653 of 859
# 654 of 859
# 655 of 859
# 656 of 859
# 657 of 859
# 658 of 859
# 659 of 859
# 660 of 859
# 661 of 859
# 662 of 859
# 663 of 859
# 664 of 859
# 665 of 859
# 666 of 859
# 667 of 859
# 668 of 859
# 669 of 859
# 670 of 859
# 671 of 859
# 672 of 859
# 673 of 859
# 674 of 859
# 675 of 859
# 676 of 859
# 677 of 859
# 678 of 859
# 679 of 859
# 680 of 859
# 681 of 859
# 682 of 859
# 683 of 859
# 684 of 859
# 685 of 859
# 686 of 859
# 687 of 859
# 688 of 859
# 689 of 859
# 690 of 859
# 691 of 859
# 692 of 859
# 693 of 859
# 694 of 859
# 695 of 859
# 696 of 859
# 697 of 859
# 698 of 859
# 699 of 859
# 700 of 859
# 701 of 859
# 702 of 859
# 703 of 859
# 704 of 859
# 705 of 859
# 706 of 859
# 707 of 859
# 708 of 859
# 709 of 859
# 710 of 859
# 711 of 859
# 712 of 859
# 713 of 859
# 714 of 859
# 715 of 859
# 716 of 859
# 717 of 859
# 718 of 859
# 719 of 859
# 720 of 859
# 721 of 859
# 722 of 859
# 723 of 859
# 724 of 859
# 725 of 859
# 726 of 859
# 727 of 859
# 728 of 859
# 729 of 859
# 730 of 859
# 731 of 859
# 732 of 859
# 733 of 859
# 734 of 859
# 735 of 859
# 736 of 859
# 737 of 859
# 738 of 859
# 739 of 859
# 740 of 859
# 741 of 859
# 742 of 859
# 743 of 859
# 744 of 859
# 745 of 859
# 746 of 859
# 747 of 859
# 748 of 859
# 749 of 859
# 750 of 859
# 751 of 859
# 752 of 859
# 753 of 859
# 754 of 859
# 755 of 859
# 756 of 859
# 757 of 859
# 758 of 859
# 759 of 859
# 760 of 859
# 761 of 859
# 762 of 859
# 763 of 859
# 764 of 859
# 765 of 859
# 766 of 859
# 767 of 859
# 768 of 859
# 769 of 859
# 770 of 859
# 771 of 859
# 772 of 859
# 773 of 859
# 774 of 859
# 775 of 859
# 776 of 859
# 777 of 859
# 778 of 859
# 779 of 859
# 780 of 859
# 781 of 859
# 782 of 859
# 783 of 859
# 784 of 859
# 785 of 859
# 786 of 859
# 787 of 859
# 788 of 859
# 789 of 859
# 790 of 859
# 791 of 859
# 792 of 859
# 793 of 859
# 794 of 859
# 795 of 859
# 796 of 859
# 797 of 859
# 798 of 859
# 799 of 859
# 800 of 859
# 801 of 859
# 802 of 859
# 803 of 859
# 804 of 859
# 805 of 859
# 806 of 859
# 807 of 859
# 808 of 859
# 809 of 859
# 810 of 859
# 811 of 859
# 812 of 859
# 813 of 859
# 814 of 859
# 815 of 859
# 816 of 859
# 817 of 859
# 818 of 859
# 819 of 859
# 820 of 859
# 821 of 859
# 822 of 859
# 823 of 859
# 824 of 859
# 825 of 859
# 826 of 859
# 827 of 859
# 828 of 859
# 829 of 859
# 830 of 859
# 831 of 859
# 832 of 859
# 833 of 859
# 834 of 859
# 835 of 859
# 836 of 859
# 837 of 859
# 838 of 859
# 839 of 859
# 840 of 859
# 841 of 859
# 842 of 859
# 843 of 859
# 844 of 859
# 845 of 859
# 846 of 859
# 847 of 859
# 848 of 859
# 849 of 859
# 850 of 859
# 851 of 859
# 852 of 859
# 853 of 859
# 854 of 859
# 855 of 859
# 856 of 859
# 857 of 859
# 858 of 859
# 859 of 859

# %%
for k,v in mb.items():
    print(k, len(v))
# Out:
# Facility Number: 859
# Phone: 859
# Region: 859
# Area: 859
# Neighbourhood: 859
# School Division: 859
# Type of Facility: 859
# Age Type: 859
# Facility Open On: 859
# Total Child Care Spaces: 859
# Address: 859
# Legal Name:  859
# Facility Director: 292

# %%
# Drop unneccessary key with missing values
mb.pop("Facility Director:")
# Out:
# ['Heather Lowe',
#  'Stephanie Sigurdson',
#  'Phyllis  Demasson',
#  'Phyllis  Demasson',
#  'Maria Warrener',
#  'Candice Saltel',
#  'Jamie Godard',
#  'Cindy Lamoureux',
#  'Noreen Breland',
#  'Colleen Steppler',
#  '',
#  'Donna Gork-Todoruk',
#  'Donna Gork-Todoruk',
#  'Tara Mills',
#  'Becky Mann',
#  'Cindy Bergen',
#  'Yvette Lacroix',
#  'Yvette Lacroix',
#  'Natalie Archambault',
#  'Lorraine Mcconnell',
#  'Rhonda Carlson',
#  'Rhonda Carlson',
#  '',
#  'Haley Lefebvre',
#  'Crystal Neepin ',
#  'Cheryl Hamilton',
#  'Cheryl Hamilton',
#  'Terri Holmgren',
#  'Bertha Hutcheson',
#  'Carol Gardiner',
#  'Melissa Puchailo',
#  'Jamie Grouette ',
#  'Darlayn Caruk',
#  'Carrie Baker',
#  'Leola Paul',
#  'Leola Paul ',
#  'Lisa Monkman',
#  'Jasmine Nault',
#  'Jane Joss',
#  'Brittany Derouin',
#  'Jenna Middleton',
#  'Jenna Middleton',
#  'Jacqueline Peters',
#  'Torey Werbicki',
#  'Kayla Rose',
#  'Tami Karsin',
#  '',
#  'Erin Cennon',
#  'Lisa Hicks',
#  'Telysha Vaneaton',
#  'Pierrette Dubois',
#  'Rachelle Muller',
#  'Syvelie Mesidor Vaneus',
#  'Brenda Gill',
#  'Brenda Gerstmar',
#  'Michele Couture',
#  'Laura Diehl',
#  'Kathleen (Kathy) Kroeker',
#  'Denyse Skoropata',
#  'Sandra Gagne',
#  'Rhonda Kenning',
#  'Rhonda-Lee Kenning',
#  'Rhonda Kenning',
#  'Laura Barthelette',
#  'Laura Barthelette',
#  'Candice Benson',
#  'Mary Ann Hudzick',
#  'Jennifer Meloney',
#  'Charlene Jasper',
#  'Shauna Richards',
#  'Joanne Gee',
#  'Jana Crossley',
#  'Bonnie Baptiste',
#  'Avere Stangeland',
#  'Sandy Gagne',
#  'Nicole Fleming',
#  'Patty Klassen',
#  'Lynn Martin',
#  'Jasmine Lafournaise',
#  'Tara Mills',
#  'Kailey Penner',
#  'Marita Rempel',
#  'Marita Rempel',
#  'Marita Rempel',
#  'Chloe Plaiser',
#  'Chloe Plaisier',
#  'Joelle Desrochers',
#  'Sheena Beattie',
#  'Sheena Beattie',
#  'Robyn Emberly',
#  'Janie Ferguson',
#  'Sherry Quach',
#  'Sara Born',
#  'Lorraine Milan',
#  'Marie Jaune',
#  'Shelby Hunter',
#  'Julliette Chabot',
#  'Isabelle Raharijaona',
#  'Andrée Rémillard',
#  'Cédelynne Lachance',
#  'Chantal Maynard',
#  'Sharon Delourme',
#  'Anick  Lia Pehe',
#  'Shelly Kullman',
#  'Hanna Drielick',
#  'Janice Enright',
#  'Dixie Pauwells',
#  'Julietta Hardiman',
#  'Randi Fleury',
#  'Bonnie Rae',
#  'Ashley Richard',
#  'Jamie Grouette',
#  'Lorie Popovits',
#  'Shuana Richards',
#  'Lenora Kerr',
#  'Candice Bugg',
#  'Kelly Unrau',
#  'Marissa Sinclair',
#  'Lauree Latimer',
#  'Terryl Green',
#  'Teresa Guillas ',
#  'Teresa Guillas ',
#  'Lauree Latimer',
#  'Shuana Richards',
#  'Colleen Steppler',
#  'Terri Lamy',
#  'Diane Erickson',
#  'Karen Vandijk',
#  'Leanne Derlago',
#  'Tammy Hall',
#  'Joanne Mitchell',
#  'Joanne Mitchell',
#  'Janie Inkster',
#  'Dayna Ledoux',
#  'Dayna Ledoux',
#  'Karen Yuriy',
#  'Holly Degraeve',
#  'Kendra Custance',
#  'Karen Vandijk',
#  'Lisa Voth',
#  'Lisa Voth',
#  'Jane Joss',
#  'Heather Adam',
#  'Sheri Phillips',
#  'Lynda Mensch',
#  'Frances Lansing',
#  'Anna-Marie Quilty',
#  'Chantel Colli',
#  'Jenifer Nick',
#  'Cynthia Thomsen',
#  '',
#  'Carley Burback',
#  'Teresa Paul',
#  'Colleen Mcgill',
#  'Marilynn Lawless',
#  'Heather Betke',
#  'Crystal Murray',
#  'Sarah Mclaren',
#  'Lorie Fiddler',
#  '',
#  '',
#  'Melanie Heinrichs',
#  ' Melanie Heinrichs  ',
#  'Lori Zenchyshyn',
#  'Betty Macrae',
#  'Shelley Conrad',
#  'Rebekah Brolund',
#  'Rebekah Brolund',
#  'Lisa Voth',
#  'Joanna Novak',
#  'Joanna Novak',
#  'Joanna Novak',
#  'Lana Redmond',
#  'Debbie Russell',
#  'Nicole Kibsey',
#  'Nicole Kibsey',
#  'Janet Goodman',
#  'Jennifer Joel',
#  'Rhonda Stasiuk',
#  'Jennifer Joel',
#  'Cynthia Miles',
#  'Roxanne Mccullough',
#  'Lisa Voth',
#  'Bonnie Caddy',
#  'Melissa Marion',
#  'Melissa Marion',
#  'Anne-Marie Bosters',
#  'Lori Malcolm',
#  'Lori Malcolm',
#  'Desiree Mayert',
#  'Carolyn Boisjoli',
#  'Christina-Lynn Nick',
#  'Heather Wilson',
#  'Pam Kelly',
#  'Kimberley Goerzen',
#  'Kailey Penner',
#  'Brenda Forster',
#  'Eileen Czerkawski',
#  'Jennifer Sims',
#  'Jennifer Sims',
#  'Jennifer Sims',
#  'Jennifer Sims',
#  'Jennifer Sims',
#  'Jean Cortez',
#  'Chelsea Zwarich',
#  'Nicole Kibsey',
#  'Wendy May',
#  'Bonnie Chartrand',
#  'Jennifer Cullen',
#  'Jennifer Cullen',
#  'Robyn Lambert',
#  'Robyn Lambert',
#  'Glenys Bertholet',
#  'Tammy Garnham',
#  'Janice Delf',
#  'Lenora Fassett',
#  'Valerie Reykdal',
#  'Rachelle Mckay',
#  'Audra Newman',
#  'Kathy Hume',
#  'Deb Berry',
#  'Patricia Gergert',
#  'Audra Newman',
#  'Ashley Stefishen',
#  'Marianne Thiessen',
#  'Brenda Deneer',
#  'Cheryl  Longley',
#  'Laurie Ann Conard',
#  'Nadine Dobbin',
#  'Kristine Janz',
#  'Brittany Thomson',
#  'Elizabeth Wollny',
#  'Brenda Brading',
#  'Janet Osborne',
#  'Kristy Penner ',
#  'Ruth Unrau',
#  'Melissa May',
#  'Shelley Conrad',
#  'Virginia Church',
#  'Helen Stone',
#  'Anita  Howatt',
#  '',
#  'Victoria Benoit',
#  'Flor Teresita Ruiz',
#  'Rhonda Boyd',
#  'Tanya Jonasson',
#  'Lisa Hicks',
#  'Pommy Palmer',
#  'Tara Friesen',
#  'Kim Tyson',
#  'Charlene Jasper',
#  'Cheryl Longley',
#  'Tammy Hossack',
#  'Lindsay Ortlieb',
#  'Kelly Patrick ',
#  'Crystal  Timm',
#  'Tammy Spridzans',
#  'Candace Demeria',
#  'Margaret Fontaine',
#  'Nadine Dobbin',
#  'Alison Lampertz',
#  'Kelly Unrau',
#  'Susan Paluch',
#  'Irene Falk',
#  'Kyla Koroscil',
#  'Krista Sargent',
#  'Marjorie Niemi',
#  'Leona Glover',
#  'Lori Carpenter',
#  'Sally Evans',
#  'Erin Derlago',
#  'Jacquie Koromah',
#  'Sandra Wilson',
#  'Marilynn Lawless',
#  'Debra Schwartz',
#  'Melanie Heinrich',
#  'Pam Staple',
#  'Kathy Magura',
#  'Diane Legault',
#  'Selma Verrier',
#  'Rachael Dube',
#  'Jennifer Gilbertson (Whalen) ',
#  'Brenda Dahr',
#  'Cathy Fafard',
#  'Wendy May',
#  'Taylor Sunaert',
#  'Tracy  Hoglander',
#  'Brittany Thiessen',
#  'Sheila Dyck',
#  'Nicole Fleming',
#  '',
#  'Janet Goodman']

# %%
MB = pd.DataFrame(mb)

# %%
MB.info()
MB.tail(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 859 entries, 0 to 858
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Facility Number          859 non-null    object
#  1   Phone                    859 non-null    object
#  2   Region                   859 non-null    object
#  3   Area                     859 non-null    object
#  4   Neighourhood             859 non-null    object
#  5   School Division          859 non-null    object
#  6   Type of Facility         859 non-null    object
#  7   Age Type                 859 non-null    object
#  8   Facility Open On         859 non-null    object
#  9   Total Child Care Spaces  859 non-null    object
#  10  Address                  859 non-null    object
#  11  Legal Name               859 non-null    object
# dtypes: object(12)
# memory usage: 80.7+ KB
#     Facility Number           Phone          Region             Area  \
# 849            9814  (204) 573-7281  Westman Region  BRANDON CENTRAL
# 850           50578  (204) 725-3343  Westman Region  BRANDON CENTRAL
# 851            7832  (204) 354-2217  Westman Region          WESTMAN
# 852            9648  (204) 720-7400  Westman Region  BRANDON CENTRAL
# 853          101099  (204) 268-4960  Eastman Region          EASTMAN
# 854          100590  (204) 857-7736  Central Region          CENTRAL
# 855            5790  (204) 866-4080  Eastman Region          EASTMAN
# 856           50578  (204) 725-3343  Westman Region  BRANDON CENTRAL
# 857            9648  (204) 720-7400  Westman Region  BRANDON CENTRAL
# 858          101099  (204) 268-4960  Eastman Region          EASTMAN
#
#            Neighourhood                     School Division Type of Facility  \
# 849     BRANDON CENTRAL             BRANDON SCHOOL DIVISION             Home
# 850     BRANDON CENTRAL             BRANDON SCHOOL DIVISION             Home
# 851           BROOKDALE    BEAUTIFUL PLAINS SCHOOL DIVISION             Home
# 852     BRANDON CENTRAL             BRANDON SCHOOL DIVISION             Home
# 853          BEAUSEJOUR             SUNRISE SCHOOL DIVISION             Home
# 854  PORTAGE LA PRAIRIE  PORTAGE LA PRAIRIE SCHOOL DIVISION             Home
# 855             LORETTE         SEINE RIVER SCHOOL DIVISION             Home
# 856     BRANDON CENTRAL             BRANDON SCHOOL DIVISION             Home
# 857     BRANDON CENTRAL             BRANDON SCHOOL DIVISION             Home
# 858          BEAUSEJOUR             SUNRISE SCHOOL DIVISION             Home
#
#                           Age Type              Facility Open On  \
# 849  Infant, Preschool, School Age            Weekdays, Evenings
# 850  Infant, Preschool, School Age  Weekdays, Evenings, Weekends
# 851  Infant, Preschool, School Age            Weekdays, Evenings
# 852  Infant, Preschool, School Age  Weekdays, Evenings, Weekends
# 853  Infant, Preschool, School Age  Weekdays, Evenings, Weekends
# 854  Infant, Preschool, School Age  Weekdays, Evenings, Weekends
# 855  Infant, Preschool, School Age            Weekdays, Evenings
# 856  Infant, Preschool, School Age  Weekdays, Evenings, Weekends
# 857  Infant, Preschool, School Age  Weekdays, Evenings, Weekends
# 858  Infant, Preschool, School Age  Weekdays, Evenings, Weekends
#
#     Total Child Care Spaces Address                          Legal Name
# 849                       7    None  Family or Group Child  Care Home *
# 850                      12    None  Family or Group Child  Care Home *
# 851                       8    None  Family or Group Child  Care Home *
# 852                       7    None  Family or Group Child  Care Home *
# 853                       8    None  Family or Group Child  Care Home *
# 854                      12    None  Family or Group Child  Care Home *
# 855                       8    None  Family or Group Child  Care Home *
# 856                      12    None  Family or Group Child  Care Home *
# 857                       7    None  Family or Group Child  Care Home *
# 858                       8    None  Family or Group Child  Care Home *

# %%
MB.groupby('Region').describe()
# Out:
#                  Facility Number                     Phone         \
#                            count unique     top freq count unique
# Region
# Central Region               121     74  100590   10   121     67
# Eastman Region               210     95  101099   13   210     90
# Interlake Region             175     79  100285    7   175     71
# NORTHERN                      43     28    9484    4    43     28
# Parkland                      82     49  101089    4    82     47
# Westman Region               228    123   50578   13   228    118
#
#                                        Area         ...  \
#                              top freq count unique  ...
# Region                                              ...
# Central Region    (204) 857-7736   10   121      1  ...
# Eastman Region    (204) 268-4960   13   210      1  ...
# Interlake Region  (204) 485-6237    7   175      1  ...
# NORTHERN          (204) 677-3247    4    43      2  ...
# Parkland          (204) 247-1030    4    82      1  ...
# Westman Region    (204) 720-7400   13   228      4  ...
#
#                  Total Child Care Spaces      Address                    \
#                                      top freq   count unique   top freq
# Region
# Central Region                         8   17     121     59  None   63
# Eastman Region                         8   59     210     55  None  154
# Interlake Region                       8   85     175     40  None  135
# NORTHERN                               8   12      43     24  None   20
# Parkland                               8   31      82     38  None   45
# Westman Region                         8   54     228     91  None  135
#
#                  Legal Name
#                       count unique                                 top freq
# Region
# Central Region          121     53  Family or Group Child  Care Home *   60
# Eastman Region          210     57  Family or Group Child  Care Home *  150
# Interlake Region        175     48  Family or Group Child  Care Home *  126
# NORTHERN                 43     24  Family or Group Child  Care Home *   20
# Parkland                 82     37  Family or Group Child  Care Home *   44
# Westman Region          228     79  Family or Group Child  Care Home *  131
#
# [6 rows x 44 columns]

# %% [markdown]
# Brandon
# ---

# %%
url2 ='https://direct3.gov.mb.ca/86256AF2006B7D4F/FacilityList?OpenForm&START=1&COUNT=1000&AGE={}&FAC=Group,%20%20Center,%20%20Nursery&OPN={}&VAC=No&MAP=Brandon&AREA=BRANDON%20CENTRAL,BRANDON%20EAST,BRANDON%20WEST,NORTH%20HILL&VIEW=P&LANG=1&ADV=No'

# %%
names_brandon = list()
links_brandon = list()


for a in ages:
    for o in opn:
        print("BRANDON", a, o)
        # change the url to iter through all age and opn options
        req2 = requests.get(url2.format(a, o), headers=headers)
        soup2 = BeautifulSoup(req2.text)
        
        tables = soup2.find_all('table')
        
        # get names and request.get links to description pages. Scrape each facility
        for l in tables[3].find_all('a'):
            names_brandon.append(l.text)
            links_brandon.append(domain+l['href'])
        
            # wait
            time.sleep(random.uniform(1,4))
# Out:
# Infant Weekdays
# Infant Weekends
# Infant Evenings
# Infant Overnight
# Preschool Weekdays
# Preschool Weekends
# Preschool Evenings
# Preschool Overnight
# Nursery Weekdays
# Nursery Weekends
# Nursery Evenings
# Nursery Overnight
# School Age Weekdays
# School Age Weekends
# School Age Evenings
# School Age Overnight

# %%
output2 = []
out_links2 = []

# remove duplicates except for those that are Family or Group Child  Care Home *

for x,l in zip(names_brandon, links_brandon):
    if l not in out_links2:
        output2.append(x)
        out_links2.append(l)
    if x == 'Family or Group Child  Care Home *':
        output2.append(x)
        out_links2.append(l)

# %%
domain = 'https://direct3.gov.mb.ca'
brandon = {}

for l,i in zip(out_links2,range(1,len(out_links2)+1)):
    print('BR - {} of {}'.format(i, len(out_links2)))
    
    r2 = requests.get(l, headers = headers)
    s2 = BeautifulSoup(r2.text)

    # scrape info
    table = s2.find_all('table')[1]
    vals = table.select('td:nth-of-type(2)')
    kys = table.select('td:nth-of-type(1)')

    # make dict
    for k,v in zip(kys, vals):
        if k.text in brandon.keys():
            brandon[k.text].append(v.text)
        else:
            brandon[k.text] = [v.text]

    # fill missing info
    if not any("Address" in k.text for k in kys):
        if "Address:" in brandon.keys():
            brandon["Address:"].append("None")
        else:
            brandon["Address:"] = ["None"]
    else:
        pass

    if not any("Legal Name" in k.text for k in kys):
        if "Legal Name: " in brandon.keys():
            brandon["Legal Name: "].append("Family or Group Child  Care Home *")
        else:
            brandon["Legal Name: "] = ["None"]
    else:
        pass

   

    # wait
    time.sleep(random.uniform(1,4))
# Out:
# 1 of 114
# 2 of 114
# 3 of 114
# 4 of 114
# 5 of 114
# 6 of 114
# 7 of 114
# 8 of 114
# 9 of 114
# 10 of 114
# 11 of 114
# 12 of 114
# 13 of 114
# 14 of 114
# 15 of 114
# 16 of 114
# 17 of 114
# 18 of 114
# 19 of 114
# 20 of 114
# 21 of 114
# 22 of 114
# 23 of 114
# 24 of 114
# 25 of 114
# 26 of 114
# 27 of 114
# 28 of 114
# 29 of 114
# 30 of 114
# 31 of 114
# 32 of 114
# 33 of 114
# 34 of 114
# 35 of 114
# 36 of 114
# 37 of 114
# 38 of 114
# 39 of 114
# 40 of 114
# 41 of 114
# 42 of 114
# 43 of 114
# 44 of 114
# 45 of 114
# 46 of 114
# 47 of 114
# 48 of 114
# 49 of 114
# 50 of 114
# 51 of 114
# 52 of 114
# 53 of 114
# 54 of 114
# 55 of 114
# 56 of 114
# 57 of 114
# 58 of 114
# 59 of 114
# 60 of 114
# 61 of 114
# 62 of 114
# 63 of 114
# 64 of 114
# 65 of 114
# 66 of 114
# 67 of 114
# 68 of 114
# 69 of 114
# 70 of 114
# 71 of 114
# 72 of 114
# 73 of 114
# 74 of 114
# 75 of 114
# 76 of 114
# 77 of 114
# 78 of 114
# 79 of 114
# 80 of 114
# 81 of 114
# 82 of 114
# 83 of 114
# 84 of 114
# 85 of 114
# 86 of 114
# 87 of 114
# 88 of 114
# 89 of 114
# 90 of 114
# 91 of 114
# 92 of 114
# 93 of 114
# 94 of 114
# 95 of 114
# 96 of 114
# 97 of 114
# 98 of 114
# 99 of 114
# 100 of 114
# 101 of 114
# 102 of 114
# 103 of 114
# 104 of 114
# 105 of 114
# 106 of 114
# 107 of 114
# 108 of 114
# 109 of 114
# 110 of 114
# 111 of 114
# 112 of 114
# 113 of 114
# 114 of 114

# %%
brandon.pop('Facility Director:')
# Out:
# ['Candice Saltel',
#  '',
#  'Lorraine Mcconnell',
#  'Bertha Hutcheson',
#  'Colleen Smith',
#  'Colleen Smith',
#  'Chloe Plaiser',
#  'Chloe Plaisier',
#  'Shelly Kullman',
#  'Lorie Popovits',
#  'Heather Adam',
#  'Eileen Czerkawski',
#  'Audra Newman',
#  'Kathy Hume',
#  'Deb Berry',
#  'Patricia Gergert',
#  'Audra Newman',
#  'Marianne Thiessen',
#  'Brittany Thomson',
#  'Melissa May',
#  '',
#  'Kayla Irwin',
#  'Tammy Hossack',
#  'Sandra Wilson',
#  'Tracy  Hoglander']

# %% [markdown]
# Winnipeg
# ---

# %%
url3 ='https://direct3.gov.mb.ca/86256AF2006B7D4F/FacilityList?OpenForm&START=1&COUNT=1000&AGE={}&FAC=Group,%20%20Center,%20%20Nursery&OPN={}&VAC=No&MAP=Winnipeg&AREA=ASSINIBOINE%20SOUTH,DOWNTOWN,FORT%20GARRY,INKSTER,POINT%20DOUGLAS,RIVER%20EAST,RIVER%20HEIGHTS,SEVEN%20OAKS,ST.BONIFACE,ST.JAMES%20ASSINIBOINE,ST.VITAL,TRANSCONA&VIEW=P&LANG=1&ADV=No'

# %%
names_winnipeg = list()
links_winnipeg = list()


for a in ages:
    for o in opn:
        print("WINNIPEG", a, o)
        # change the url to iter through all age and opn options
        req3 = requests.get(url3.format(a, o), headers=headers)
        soup3 = BeautifulSoup(req3.text)
        
        tables = soup3.find_all('table')
        
        # get names and request.get links to description pages. Scrape each facility
        for l in tables[3].find_all('a'):
            names_winnipeg.append(l.text)
            links_winnipeg.append(domain+l['href'])
        
            # wait
            time.sleep(random.uniform(1,4))
# Out:
# Infant Weekdays
# Infant Weekends
# Infant Evenings
# Infant Overnight
# Preschool Weekdays
# Preschool Weekends
# Preschool Evenings
# Preschool Overnight
# Nursery Weekdays
# Nursery Weekends
# Nursery Evenings
# Nursery Overnight
# School Age Weekdays
# School Age Weekends
# School Age Evenings
# School Age Overnight

# %%
output3 = []
out_links3 = []

# remove duplicates except for those that are Family or Group Child  Care Home *

for x,l in zip(names_winnipeg, links_winnipeg):
    if l not in out_links3:
        output3.append(x)
        out_links3.append(l)
    if x == 'Family or Group Child  Care Home *':
        output3.append(x)
        out_links3.append(l)

# %%
domain = 'https://direct3.gov.mb.ca'
winnipeg = {}

# %%
for l,i in zip(out_links3,range(176,len(out_links3)+1)):
    print('wpg - {} of {}'.format(i, len(out_links3)))
    
    r3 = requests.get(l, headers = headers)
    s3 = BeautifulSoup(r3.text)

    # scrape info
    table = s3.find_all('table')[1]
    vals = table.select('td:nth-of-type(2)')
    kys = table.select('td:nth-of-type(1)')

    # make dict
    for k,v in zip(kys, vals):
        if k.text in winnipeg.keys():
            winnipeg[k.text].append(v.text)
        else:
            winnipeg[k.text] = [v.text]

    # fill missing info
    if not any("Address" in k.text for k in kys):
        if "Address:" in winnipeg.keys():
            winnipeg["Address:"].append("None")
        else:
            winnipeg["Address:"] = ["None"]
    else:
        pass

    if not any("Legal Name" in k.text for k in kys):
        if "Legal Name: " in winnipeg.keys():
            winnipeg["Legal Name: "].append("Family or Group Child  Care Home *")
        else:
            winnipeg["Legal Name: "] = ["None"]
    else:
        pass

   

    # wait
    time.sleep(random.uniform(1,4))
# Out:
# 176 of 1311
# 177 of 1311
# 178 of 1311
# 179 of 1311
# 180 of 1311
# 181 of 1311
# 182 of 1311
# 183 of 1311
# 184 of 1311
# 185 of 1311
# 186 of 1311
# 187 of 1311
# 188 of 1311
# 189 of 1311
# 190 of 1311
# 191 of 1311
# 192 of 1311
# 193 of 1311
# 194 of 1311
# 195 of 1311
# 196 of 1311
# 197 of 1311
# 198 of 1311
# 199 of 1311
# 200 of 1311
# 201 of 1311
# 202 of 1311
# 203 of 1311
# 204 of 1311
# 205 of 1311
# 206 of 1311
# 207 of 1311
# 208 of 1311
# 209 of 1311
# 210 of 1311
# 211 of 1311
# 212 of 1311
# 213 of 1311
# 214 of 1311
# 215 of 1311
# 216 of 1311
# 217 of 1311
# 218 of 1311
# 219 of 1311
# 220 of 1311
# 221 of 1311
# 222 of 1311
# 223 of 1311
# 224 of 1311
# 225 of 1311
# 226 of 1311
# 227 of 1311
# 228 of 1311
# 229 of 1311
# 230 of 1311
# 231 of 1311
# 232 of 1311
# 233 of 1311
# 234 of 1311
# 235 of 1311
# 236 of 1311
# 237 of 1311
# 238 of 1311
# 239 of 1311
# 240 of 1311
# 241 of 1311
# 242 of 1311
# 243 of 1311
# 244 of 1311
# 245 of 1311
# 246 of 1311
# 247 of 1311
# 248 of 1311
# 249 of 1311
# 250 of 1311
# 251 of 1311
# 252 of 1311
# 253 of 1311
# 254 of 1311
# 255 of 1311
# 256 of 1311
# 257 of 1311
# 258 of 1311
# 259 of 1311
# 260 of 1311
# 261 of 1311
# 262 of 1311
# 263 of 1311
# 264 of 1311
# 265 of 1311
# 266 of 1311
# 267 of 1311
# 268 of 1311
# 269 of 1311
# 270 of 1311
# 271 of 1311
# 272 of 1311
# 273 of 1311
# 274 of 1311
# 275 of 1311
# 276 of 1311
# 277 of 1311
# 278 of 1311
# 279 of 1311
# 280 of 1311
# 281 of 1311
# 282 of 1311
# 283 of 1311
# 284 of 1311
# 285 of 1311
# 286 of 1311
# 287 of 1311
# 1268 of 1311
# 1269 of 1311
# 1270 of 1311
# 1271 of 1311
# 1272 of 1311
# 1273 of 1311
# 1274 of 1311
# 1275 of 1311
# 1276 of 1311
# 1277 of 1311
# 1278 of 1311
# 1279 of 1311
# 1280 of 1311
# 1281 of 1311
# 1282 of 1311
# 1283 of 1311
# 1284 of 1311
# 1285 of 1311
# 1286 of 1311
# 1287 of 1311
# 1288 of 1311
# 1289 of 1311
# 1290 of 1311
# 1291 of 1311
# 1292 of 1311
# 1293 of 1311
# 1294 of 1311
# 1295 of 1311
# 1296 of 1311
# 1297 of 1311
# 1298 of 1311
# 1299 of 1311
# 1300 of 1311
# 1301 of 1311
# 1302 of 1311
# 1303 of 1311
# 1304 of 1311
# 1305 of 1311
# 1306 of 1311
# 1307 of 1311
# 1308 of 1311
# 1309 of 1311
# 1310 of 1311
# 1311 of 1311

# %%
for k,v in winnipeg.items():
    print(k, len(v))
# Out:
# Facility Number: 1311
# Phone: 1311
# Region: 1311
# Area: 1311
# Neighbourhood: 1311
# School Division: 1311
# Type of Facility: 1311
# Age Type: 1311
# Facility Open On: 1311
# Total Child Care Spaces: 1311
# Address: 1311
# Legal Name:  1311
# Facility Director: 750

# %%
winnipeg.pop('Facility Director:')
# Out:
# ['Candice Saltel',
#  '',
#  '',
#  'Lorraine Mcconnell',
#  'Bertha Hutcheson',
#  'Bertha Hutcheson',
#  'Colleen Smith',
#  'Colleen Smith',
#  'Colleen Smith',
#  'Colleen Smith',
#  'Chloe Plaiser',
#  'Chloe Plaiser',
#  'Chloe Plaisier',
#  'Shelly Kullman',
#  'Lorie Popovits',
#  'Lorie Popovits',
#  'Heather Adam',
#  'Eileen Czerkawski',
#  'Eileen Czerkawski',
#  'Audra Newman',
#  'Audra Newman',
#  'Kathy Hume',
#  'Deb Berry',
#  'Deb Berry',
#  'Patricia Gergert',
#  'Audra Newman',
#  'Marianne Thiessen',
#  'Bertha Hutcheson',
#  'Audra Newman',
#  'Audra Newman',
#  'Brittany Thomson',
#  'Melissa May',
#  '',
#  '',
#  'Kayla Irwin',
#  'Tammy Hossack',
#  'Tammy Hossack',
#  'Sandra Wilson',
#  'Sandra Wilson',
#  'Tracy  Hoglander',
#  'Kathy Hume',
#  'Marianne Thiessen',
#  'Lorraine Mcconnell',
#  'Bertha Hutcheson',
#  'Chloe Plaiser',
#  'Lorie Popovits',
#  'Candice Saltel',
#  '',
#  'Colleen Smith',
#  'Heather Adam',
#  'Bertha Hutcheson',
#  'Shelly Kullman',
#  'Heather Adam',
#  'Eileen Czerkawski',
#  'Audra Newman',
#  'Kathy Hume',
#  'Deb Berry',
#  'Patricia Gergert',
#  'Brittany Thomson',
#  '',
#  'Kayla Irwin',
#  'Sandra Wilson',
#  'Tracy  Hoglander',
#  'Kathy Hume',
#  'Candice Saltel',
#  'Tammy Hossack',
#  'Sandra Wilson',
#  'Audra Newman',
#  'Kathy Hume',
#  'Deb Berry',
#  'Patricia Gergert',
#  'Truc Tran',
#  'Brenda Paley',
#  'Hermeet Dhanjal',
#  'Sandy Mcdonald',
#  'Robyn Avery',
#  'Robyn Avery',
#  'Robyn Avery',
#  'Amanda Lavoie',
#  'Elaine Morris',
#  'Elaine Morris',
#  'Candice Saltel',
#  '',
#  '',
#  'Lorraine Mcconnell',
#  'Bertha Hutcheson',
#  'Bertha Hutcheson',
#  'Colleen Smith',
#  'Colleen Smith',
#  'Colleen Smith',
#  'Colleen Smith',
#  'Chloe Plaiser',
#  'Chloe Plaiser',
#  'Chloe Plaisier',
#  'Shelly Kullman',
#  'Lorie Popovits',
#  'Lorie Popovits',
#  'Heather Adam',
#  'Eileen Czerkawski',
#  'Eileen Czerkawski',
#  'Audra Newman',
#  'Audra Newman',
#  'Kathy Hume',
#  'Deb Berry',
#  'Deb Berry',
#  'Patricia Gergert',
#  'Audra Newman',
#  'Marianne Thiessen',
#  'Bertha Hutcheson',
#  'Audra Newman',
#  'Audra Newman',
#  'Brittany Thomson',
#  'Melissa May',
#  '',
#  '',
#  'Kayla Irwin',
#  'Tammy Hossack',
#  'Tammy Hossack',
#  'Sandra Wilson',
#  'Sandra Wilson',
#  'Tracy  Hoglander',
#  'Kathy Hume',
#  'Marianne Thiessen',
#  'Lorraine Mcconnell',
#  'Bertha Hutcheson',
#  'Chloe Plaiser',
#  'Lorie Popovits',
#  'Candice Saltel',
#  '',
#  'Colleen Smith',
#  'Heather Adam',
#  'Bertha Hutcheson',
#  'Shelly Kullman',
#  'Heather Adam',
#  'Eileen Czerkawski',
#  'Audra Newman',
#  'Kathy Hume',
#  'Deb Berry',
#  'Patricia Gergert',
#  'Brittany Thomson',
#  '',
#  'Kayla Irwin',
#  'Sandra Wilson',
#  'Tracy  Hoglander',
#  'Kathy Hume',
#  'Candice Saltel',
#  'Tammy Hossack',
#  'Sandra Wilson',
#  'Audra Newman',
#  'Kathy Hume',
#  'Deb Berry',
#  'Patricia Gergert',
#  'Truc Tran',
#  'Brenda Paley',
#  'Hermeet Dhanjal',
#  'Sandy Mcdonald',
#  'Robyn Avery',
#  'Robyn Avery',
#  'Robyn Avery',
#  'Amanda Lavoie',
#  'Elaine Morris',
#  'Elaine Morris',
#  'Pina  Zammito',
#  'Charlene Paolucci',
#  'Charlene Paolucci',
#  'Charlene Paolucci',
#  'Marilyn Valgardson',
#  'Marilyn Valgardson',
#  'Marilyn Valgardson',
#  'Marilyn Valgardson',
#  'Ashleigh Maryk',
#  'Chayna Lowe',
#  'Jennifer Grove',
#  'Jennifer Grove',
#  'Teresa Muirhead',
#  'Teresa Muirhead',
#  'Teresa Muirhead',
#  'Teresa Muirhead',
#  'Tanya Gallant',
#  'Tanya Gallant',
#  'Christina Kazmierczak',
#  'Christina Kazmierczak',
#  'Amanda Lavoie',
#  'Amanda Lavoie',
#  'Bree Macgillivray ',
#  'Bree Macgillivray ',
#  'Heather Seniuk',
#  'Heather Seniuk',
#  'Lori Renton',
#  'Lori Renton',
#  'Kimberley Hamilton',
#  'Kimberley Hamilton',
#  'Karolina Dressler',
#  'Rilla Drobot',
#  'Rilla Drobot',
#  'Jeannie Bouvier',
#  'Jeannie Bouvier',
#  'Colleen Lussier ',
#  'Colleen Lussier ',
#  'Sheila Argue',
#  'Donna Si',
#  'Donna Si',
#  'Donna  Si',
#  'Lori Chaikowski',
#  'Lori Chaikowski',
#  'Lori Chaikowski',
#  'Tannis Hewitt',
#  'Tannis Hewitt',
#  'Tannis Hewitt',
#  'Tannis Hewitt',
#  'Dawn Montebruno',
#  'Dawn Montebruno',
#  'Tracy Cosser',
#  'Tracy Cosser',
#  'Tracy Cosser',
#  'Francesca Felizardo',
#  'Francesca Felizardo',
#  'Darlene Kupchak-Heiland',
#  'Chelsea Tataryn ',
#  'Janice Childs',
#  'Janice Childs',
#  'Aricelle Mateo',
#  'Lorraine Barnett',
#  'Lorraine Barnett',
#  'Siham El Aoufir',
#  'Siham El Aoufir',
#  'Adina Altein',
#  'Adina Altein',
#  'Marla Macgregor',
#  'Ashleigh Maryk',
#  'Ashleigh Maryk',
#  'Kim Lalonde',
#  'Caroline Lenabat',
#  'Caroline Lenabat',
#  'Racquel Giesbrecht',
#  'Laura Allen',
#  'Mandeep Kaur',
#  'Laura Goodman',
#  'Laurie Lamont',
#  'Renee Laviolette',
#  'Johanna Paul',
#  'Carol  Coburn',
#  'Carol  Coburn',
#  'Giovanna Evinger',
#  'Carolyn Young',
#  'Deborah Marasa',
#  'Robyn Burnet',
#  'Robyn Burnet',
#  'Fernanda Hodgson',
#  'Muriel Cornish',
#  'Fernanda Hodgson',
#  'Fernanda Hodgson',
#  'Paramjit  Brar ',
#  'Paramjit  Brar ',
#  'Ron Blatz',
#  'Rhonda Mclennan',
#  'Rhonda Mclennan',
#  'Karen Howgate',
#  'Karen  Howgate',
#  'Heather Seniuk',
#  'Amanda Bokovay',
#  'Lynda Raible',
#  'Lori Rogalsky',
#  'Stephania Kostiuk',
#  'Stephania Kostiuk',
#  'Jan Crielaard',
#  'Ashleigh Maryk',
#  'Jan Crielaard',
#  'Caryn Lafleche',
#  'Lucille Leclerc',
#  'Clarice Egan',
#  'Clarice Egan',
#  'Deepa Raghavan',
#  'Tracy Peters',
#  'Tracy  Peters',
#  'Tracy  Peters',
#  'Colleen Barnett',
#  'Connie Mozdzen',
#  'Lisa Treft',
#  'Kerri Kelly',
#  'Kerri Kelly',
#  'Kerri Kelly',
#  'Kerri Kelly',
#  'Jodi Robillard',
#  'Jodi Robillard ',
#  'Jodi Robillard ',
#  'Jodi Robillard',
#  'Jodi Robillard',
#  'Jodi Robillard',
#  'Bonnie Krueger',
#  'Susan Moscovitch',
#  'Susan Moscovitch',
#  'Wanda  Bruenig',
#  'Wanda Bruenig',
#  'Wanda Bruenig',
#  'Caryn Lafleche',
#  '',
#  '',
#  'Jodi Ramgotra',
#  'Anick Lia-Pehe',
#  'Kim Brown',
#  'Amanda Lavoie',
#  'Cheryl Esson',
#  'Cheryl Esson',
#  'Cheryl Esson',
#  'Cheryl Esson',
#  'Johanna Paul',
#  'Mihaela Mujcinovic',
#  'Mihaela Mujcinovic',
#  'Sandy Sutherland',
#  '',
#  'Sandy Sutherland',
#  'Sandy Sutherland',
#  'Sandy Sutherland',
#  'Sandy Sutherland',
#  'Dori-Lyn Henaire',
#  'Debbie Love',
#  'Debbie Love',
#  'Kara  Kreutzer ',
#  'Shannon Curtaz',
#  'Shannon Curtaz',
#  'Shannon  Curtaz',
#  'Rita Chand',
#  'Linda Blair',
#  'Pat Furman',
#  'Pat Furman',
#  'Marilyn Catellier',
#  'Marilyn Catellier',
#  'Marilyn Catellier',
#  'Cindy Pauls',
#  'Karen Ohlson',
#  'Karen Ohlson',
#  'Karen Ohlson',
#  'Karen Ohlson',
#  'Karen Ohlson (Executive)',
#  'Karen Ohlson (Executive)',
#  'Jacqueline  Poersch-Burns',
#  'Cheryl Mendella',
#  'Mary Ellen Smith',
#  'Sidhu Satwinder',
#  'Heather Seniuk',
#  'Debbie Kessler',
#  'Dawn Forbes',
#  'Dawn Forbes',
#  'Heather  Olson ',
#  'Tara Nault',
#  'Marla Pruden-Shebaylo',
#  'Irene Semaniuk',
#  'Neelam Sekhri',
#  'Jennifer Brandstrom',
#  'Jennifer Brandstrom',
#  'Jana Currie',
#  'Marie Rosset',
#  'Cathy Gardiner',
#  'Catherine Sam',
#  'Beata Maire',
#  'Michele Demarcke',
#  'Lisa Hunnie',
#  'Marilyn Bosc',
#  'Haoua Issa Moussa Gamreke',
#  'Stephania Kostiuk ',
#  'Sharon Allen',
#  'Marian Rands',
#  'Marian Rands',
#  'Sandy Carrette',
#  'Joanna Grierson',
#  'Debbi Peterson',
#  'Debbi Peterson',
#  'Debbi Peterson',
#  'Natalie Hemminger',
#  'Natalie Hemminger',
#  'Charlene Beleyowski',
#  'Charlene Beleyowski',
#  'Carol Jones',
#  'Candice Savage',
#  'Candice Savage',
#  'Candice Savage ',
#  'Heather Seniuk',
#  'Heather Seniuk',
#  '',
#  '',
#  'Lisa Nemetchek',
#  'Lisa Nemetchek',
#  '',
#  'Victoria Hale',
#  'April Kalyniuk',
#  'Karen Taylor',
#  'Brenda Berens',
#  'Brenda Berens',
#  'Tanya Linklater',
#  'Tanya Linklater',
#  'Tanya Linklater',
#  'Tanya Linklater',
#  'Megan Turner',
#  'Megan Turner',
#  'Karen Ste. Marie',
#  'Karen Ste. Marie',
#  'Carolyn Young',
#  'Susan Madzik',
#  'Susan Madzik',
#  'Dawn Tocci',
#  'Karen Dobrucki',
#  'Karen Dobrucki',
#  'Pat Pankewycz',
#  'Pat Pankewycz',
#  'Lois Johnson',
#  'Lois Johnson',
#  '',
#  'April  Beauregard',
#  'April  Beauregard',
#  'Bonnie Ash',
#  'Bonnie Ash',
#  'Bonnie Ash',
#  'Bonnie Ash',
#  'Bonnie Ash',
#  'Bonnie Ash',
#  'Bonnie Ash',
#  'Bonnie Ash',
#  'Bonnie Ash',
#  'Bonnie Ash',
#  'Bonnie Ash',
#  'Bonnie Ash',
#  'Bonnie Ash',
#  'Melanie Fraser',
#  'Melanie Fraser',
#  'Melanie Fraser',
#  'Silvana Passante-Cantafio',
#  'Lois Coward',
#  'Lois Coward',
#  'Tracy Krulicki',
#  'Tracy Krulicki',
#  'Margaret Umbach',
#  'Margaret Umbach',
#  'Anna Mae Clark',
#  'Anna Mae Clark',
#  'Geethani Yakandawala',
#  'Geethani Yakandawala ',
#  'Brenda Bachinsky',
#  'Brenda Bachinsky',
#  'Brenda Bachinsky',
#  'Brenda Bachinsky',
#  'Brenda Bachinsky',
#  'Karlin Mann',
#  'Susan Brown',
#  'Susan Brown',
#  'Linda Herman',
#  'Joanne Gehman',
#  ' Micheline  Fay',
#  'Lileena Mendis',
#  'Lileena Mendis',
#  'Alison Stewart',
#  'Alison Stewart',
#  'Don Milberg',
#  'Don Milberg',
#  'Ryan Purpur',
#  'Katherine Gagnon',
#  'Katherine Gagnon',
#  'Katherine Gagnon',
#  'Mariella Carr',
#  'Irene Semaniuk',
#  'Irene Semaniuk',
#  'Irene Semaniuk',
#  'Irene Semaniuk',
#  'Carolyn Young',
#  'Christie De Jong',
#  'Susan Sydorchuk',
#  'Lisa Borsa',
#  'Lisa Borsa',
#  'Eleonora Caporalini',
#  'Eleonora Caporalini',
#  'Eleonora Caporalini',
#  'Brenda Charriere',
#  'Brenda Charriere',
#  'Brenda Charriere',
#  'Brenda Charriere',
#  'Brenda Charriere',
#  'Brenda Charriere',
#  'Brenda Charriere',
#  'Brenda Charriere',
#  'Brenda Charriere ',
#  'Brenda Charriere',
#  'Pam Michalenko',
#  'Asha Edirisinghe ',
#  'Karen Dobrucki',
#  'Karen Dobrucki',
#  'Momindra Slawik',
#  'Momindra Slawik',
#  'Gerrie Stolz',
#  'Debbie Russell',
#  'Michelle Lange',
#  'Michelle Lange',
#  'Erin Braun',
#  'Natasha Keith',
#  'Sabrina Manicom',
#  'Sabrina Manicom',
#  'Constance Cava',
#  'Amanda Lavoie',
#  'Sheri Billington',
#  'Limei Lin',
#  'Stephania Kostiuk',
#  'Stephania Kostiuk',
#  'Lesley Massey',
#  'Vera Shawarsky',
#  'Irene Anzaka',
#  'Susana Lam',
#  'Susana Lam',
#  'Cindy Minsky- Vincent',
#  'Janet Garant',
#  'Charnjit Bains',
#  'Joanne Larson',
#  'Ardis Martyniuk',
#  'Ardis Martyniuk',
#  'Arla Sigfusson ',
#  'Arla Sigfusson ',
#  'Alison Gregory',
#  'Alison Gregory',
#  'Heather Seniuk',
#  'Rosaleen Jackson',
#  'Rosaleen Jackson',
#  'Bev Levine',
#  'Heather Dyck',
#  'Debra Vertz',
#  'Debra Vertz',
#  'Lesley Massey',
#  'Debbie Huebner',
#  'Debbie Huebner',
#  'Tannis Piper',
#  'Tannis Piper',
#  'Lee Foon Lim',
#  'Lee Foon Lim',
#  'Shawna Masters',
#  'Shawna Masters',
#  'Kent Stevenson',
#  'Kent Stevenson',
#  'Kent Stevenson',
#  'Caryn Lafleche',
#  'Caryn Lafleche',
#  'Sherri Dean',
#  'Sherri Dean',
#  'Laura Burla',
#  'Alanna Newman',
#  'Leslie Nutbean',
#  'Leslie Nutbean',
#  'Tammy Beaudry',
#  'Tammy Beaudry',
#  'Soraya Bader',
#  'Lianne Picton',
#  'Lianne Picton',
#  'Wendy  Mcknight',
#  'Sherry Oliver',
#  'Lisa Hrechkosy',
#  'Jamie Snydal',
#  'Jamie Snydal',
#  'Michelle  Blanchard',
#  'Mary Jane Farrow',
#  'Laurinda Neyron',
#  'Laurinda Neyron',
#  'Barbara Peters',
#  'Sandra Rego',
#  'Tracy Fotiuk',
#  'Jenny Sendall',
#  'Amanda Lavoie',
#  'Amanda Lavoie',
#  'Sharon Stewner',
#  'Lisa Harakal',
#  'Jada Middaugh',
#  'Constance Cava',
#  'Constance Cava',
#  'Angela Fry ',
#  'Maria Myskiw',
#  'Jessica Smith',
#  'Jessica Smith',
#  'Jennifer Stewart',
#  'Jennifer Stewart',
#  'Darcy Orvis',
#  'Ioulia  Berdnikova',
#  'Lori  Thorvaldson',
#  'Shashwati Shome',
#  'Kelly Byman',
#  'Marguerite Lambert',
#  'Angela Nieckarz',
#  'Nidene  Johnson',
#  'Nidene Johnson',
#  'Cheryl Mendella',
#  'Dawne Doyle',
#  'Dawne Doyle',
#  'Dawne Doyle',
#  'Dawne Doyle',
#  'Dawna Cross',
#  'Shelly Loeppky',
#  'Shelly Loeppky',
#  'Jenessa Balala',
#  'Sheila Schepp',
#  'Greg Blanco',
#  'Tracy Bijl',
#  'Tracy Bijl',
#  'Ashleigh Maryk',
#  'Cheryl Crompton',
#  'Amrita Premdas',
#  'Amrita Premdas',
#  'Amrita Premdas',
#  'Amrita Premdas',
#  'Catherine Ogonoski',
#  'Michelle Welch',
#  'Michelle Welch',
#  'Michelle Welch',
#  'Michelle Welch',
#  'Laurie Lamont',
#  'Laurie Lamont',
#  'Courtney Ritsema',
#  'Courtney Ritsema',
#  'Lidan  Xu',
#  'Lidan  Xu',
#  'Nadine Mackenzie',
#  'Nadine Mackenzie',
#  'Noelle Campbell ',
#  'Constance Cava',
#  'Caryn Lafleche',
#  'Caryn La Fleche',
#  'Constance Cava',
#  'Constance Cava',
#  'Caryn Lafleche',
#  'Caryn Lafleche',
#  'Constance Cava',
#  'Caryn Lafleche',
#  'Caryn Lafleche',
#  'Caryn Lafleche',
#  'Ashleigh Maryk',
#  'Ashleigh Maryk',
#  'Ashleigh Maryk',
#  'Ashley   Haub ',
#  'Ashley   Haub ',
#  'Constance Cava',
#  'Constance Cava',
#  'Constance Cava',
#  'Constance Cava',
#  'Ashleigh Maryk',
#  'Heather Seniuk',
#  'Heather Seniuk',
#  'Constance Cava',
#  'Constance Cava',
#  'Maizie Taylor',
#  'Karolina Dressler',
#  'Ron Blatz',
#  'Brenda Charriere',
#  'Lucille Leclerc',
#  'Silvana Passante-Cantafio',
#  'Katherine Gagnon',
#  'Mariella Carr',
#  'Courtney Ritsema',
#  'Amanda Lavoie',
#  'Marilyn Valgardson',
#  'Marilyn Valgardson',
#  'Chayna Lowe',
#  'Teresa Muirhead',
#  'Teresa Muirhead',
#  'Tanya Gallant',
#  'Bree Macgillivray ',
#  'Heather Seniuk',
#  'Lori Renton',
#  'Lori Renton',
#  'Kimberley Hamilton',
#  'Jeannie Bouvier',
#  'Colleen Lussier ',
#  'Donna Si',
#  'Donna Si',
#  'Lori Chaikowski',
#  'Tannis Hewitt',
#  'Francesca Felizardo',
#  'Francesca Felizardo',
#  'Darlene Kupchak-Heiland',
#  'Chelsea Tataryn ',
#  'Janice Childs',
#  'Lisa Sirack',
#  'Caroline Lenabat',
#  'Laura Allen',
#  'Giovanna Evinger',
#  'Fernanda Hodgson',
#  'Lynda Raible',
#  'Kerri Kelly',
#  'Jodi Robillard',
#  'Susan Moscovitch',
#  'Susan Moscovitch',
#  'Kim Brown',
#  'Karen Ohlson',
#  'Cheryl Mendella',
#  'Sidhu Satwinder',
#  'Debbie Kessler',
#  'Dawn Forbes',
#  'Jana Currie',
#  'Carol Jones',
#  'Lisa Nemetchek',
#  '',
#  'Victoria Hale',
#  'April Kalyniuk',
#  'April Kalyniuk',
#  'Megan Turner',
#  'Karen Ste. Marie',
#  'Donna-Mae Dunning',
#  'Donna-Mae Dunning',
#  'Susan Madzik',
#  'Dawn Tocci',
#  'Bonnie Ash',
#  'Don Milberg',
#  'Ryan Purpur',
#  'Katherine Gagnon',
#  'Katherine Gagnon',
#  'Irene Semaniuk',
#  'Irene Semaniuk',
#  'Carolyn Young',
#  'Christie De Jong',
#  'Susan Sydorchuk',
#  'Eleonora Caporalini',
#  'Brenda Charriere',
#  'Brenda Charriere',
#  'Brenda Charriere',
#  'Brenda Charriere',
#  'Pam Michalenko',
#  'Momindra Slawik',
#  'Katie George',
#  'Sheri Billington',
#  'Limei Lin',
#  'Irene Anzaka',
#  'Debbie Huebner',
#  'Tannis Piper',
#  'Leslie Nutbean',
#  'Tammy Beaudry',
#  'Jamie Snydal',
#  'Mary Jane Farrow',
#  'Laurinda Neyron',
#  'Barbara Peters',
#  'Tracy Fotiuk',
#  'Jenny Sendall',
#  'Maria Myskiw',
#  'Marguerite Lambert',
#  'Cheryl Mendella',
#  'Dawne Doyle',
#  'Catherine Ogonoski',
#  'Michelle Welch',
#  'Laurie Lamont',
#  'Caryn Lafleche',
#  'Constance Cava',
#  'Caryn Lafleche',
#  'Constance Cava',
#  'Colleen Lussier',
#  'Colleen Lussier',
#  'Caryn Lafleche',
#  'Ashleigh Maryk',
#  'Constance Cava',
#  'Lucille Leclerc']

# %% [markdown]
# Merge, clean, export:

# %%
br = pd.DataFrame(brandon)

# %%
wp = pd.DataFrame(winnipeg)

# %%
MB_all = pd.concat([br,wp,MB])

# %%
MB_all.columns = ['Facility Number', 'Phone', 'Region', 'Area', 'Neighourhood', 'School Division', 'Type of Facility', 
                     'Age Type', 'Facility Open On', 'Total Child Care Spaces', 'Address', 'Legal Name']

# %%
MB_all['Legal Name'].replace({"None" : "Family or Group Child  Care Home *"}, inplace = True)

# %%
MB_all.Address = MB_all.Address.replace("\n", " ", regex = True)

# %%
MB_all.to_csv("data/childcare/MB-childcare.csv")

# %% [markdown]
# <mark> N.B. * We have not published the names and addresses of Family and Group Facilities for security reasons. Please contact these facilities for further information including their location </mark>
